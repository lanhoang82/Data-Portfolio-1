# %% [markdown]
# # Model 6: Boosting

# %% [markdown]
# ## Import the libraries and cleaning the dataset

# %%
### Importing the libraries
import numpy as np
import pandas as pd
#from sklearnex import patch_sklearn

#patch_sklearn()

#plotting lib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


#Sklearn Lib metrics
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV, KFold

# Pipelines : 
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn import set_config

#GradientBoostingClassifier and AdaboostClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier

#Missing values : 
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import KNNImputer, IterativeImputer, SimpleImputer
import missingno as msno

#Dummy
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn. preprocessing import StandardScaler


pd.set_option("display.max_columns",None)

# %%
train_df = pd.read_csv("Data/train.csv")
test_df = pd.read_csv("Data/test.csv")
#removing id for train_df
train_df.drop("id", axis = 1, inplace = True)

# %%
# Transforming object into categories 
# for train
for i in train_df.columns:
    if train_df[i].dtypes == "object":
        train_df[i] = train_df[i].astype("category")
# For test
for i in test_df.columns:
    if test_df[i].dtypes == "object":
        test_df[i] = test_df[i].astype("category")

# %%
X = train_df.drop("high_income", axis = 1)
y = train_df["high_income"]

# %%
# Grouping our features that are categories in one vector
# Same for numeric

categorical_features = [i for i in X.columns if X[i].dtype.name == "category"]
numerical_features = [i for i in X.columns if X[i].dtype.name != "category"]

# %% [markdown]
# ## Boosting general comment and information

# %% [markdown]
# - Fitting small tree that are slowly learning to improve the f_hat in order to improve the errors that were made
# - 3 Tuning parameter : number of trees, Shrinkage parameter lambda (learning rate) and the max depth / splits of each tree d (1 or 2 works well)

# %% [markdown]
# # AdaBoost

# %% [markdown]
# ## First try with AdaBoost

# %% [markdown]
# In case of Adaptive Boosting or AdaBoost, it minimises the exponential loss function that can make the algorithm sensitive to the outliers. With Gradient Boosting, any differentiable loss function can be utilised. Gradient Boosting algorithm is more robust to outliers than AdaBoost.
#
# https://analyticsindiamag.com/adaboost-vs-gradient-boosting-a-comparison-of-leading-boosting-algorithms/#:~:text=outliers%20than%20AdaBoost.-,Flexibility,Boosting%20more%20flexible%20than%20AdaBoost

# %% [markdown]
# - The base estimator will be a classification tree with depth. = 1

# %%
numeric_transformer = Pipeline(
    steps=[("imputer_num", SimpleImputer(strategy="mean")),
           ("scaler", StandardScaler())]
)

categorical_transformer = Pipeline(
    steps=[("imputer_cat", SimpleImputer(strategy="constant", fill_value="Missing")),
           
           ("encoder" , OneHotEncoder(handle_unknown="ignore", sparse=False))]
)



preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", AdaBoostClassifier(random_state = 10))]
)


set_config(display="diagram")
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'mig_move_reg', 'hs_college',
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier', AdaBoostClassifier(random_state=10))])

# %%
#Learning rate : Weight applied to each classifier at each boosting iteration. 
#A higher learning rate increases the contribution of each classifier. 
#There is a trade-off between the learning_rate and n_estimators parameters. 
#Values must be in the range (0.0, inf).

hyper_param = {"classifier__n_estimators":np.arange(50,250,50),
              "classifier__learning_rate":np.linspace(10**-4, 1,10)}
adaboost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
np.linspace(10**-4, 1,10)
# Out:
# array([1.000e-04, 1.112e-01, 2.223e-01, 3.334e-01, 4.445e-01, 5.556e-01,
#        6.667e-01, 7.778e-01, 8.889e-01, 1.000e+00])

# %%
adaboost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         AdaBoostClassifier(random_state=10))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': array([1.000e-04, 1.112e-01, 2.223e-01, 3.334e-01, 4.445e-01, 5.556e-01,
#        6.667e-01, 7.778e-01, 8.889e-01, 1.000e+00]),
#                          'classifier__n_estimators': array([ 50, 100, 150, 200])},
#              scoring='accuracy', verbose=1)

# %%
cv_res = pd.DataFrame(adaboost_pipe_cv.cv_results_)
cv_res
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       57.190209      2.849433         1.773595        0.122916
# 1      133.308290      6.859897         3.102178        0.524109
# 2      159.021076     21.719599         4.146591        0.453067
# 3      229.994725     12.715532         6.786923        0.318177
# 4       59.674941      1.875025         1.741645        0.120127
# 5      110.675882      6.475088         3.007465        0.409758
# 6      149.527171     12.175515         4.400306        0.592401
# 7      232.734885      6.335055         6.370712        0.222273
# 8       64.475891      4.794022         1.876331        0.161303
# 9      120.730401      3.483841         4.358252        1.099456
# 10     173.508220     15.447460         4.265799        0.312283
# 11     204.490318     12.166789         6.063577        0.578116
# 12      58.370236      1.364035         2.244165        0.770954
# 13     109.744076      5.254852         2.896722        0.279975
# 14     147.935226     10.408754         4.294671        0.578329
# 15     234.057355      9.755571         7.414649        0.650186
# 16      64.165132      3.866387         1.802631        0.117339
# 17     132.420201      3.617671         3.613174        0.186762
# 18     186.526166      2.922306         5.026136        0.192347
# 19     240.496635      0.982296         6.792965        0.894534
# 20      61.861883      0.970267         1.874193        0.056966
# 21     123.292414      3.382949         3.484833        0.263969
# 22     187.457748      3.830845         4.905474        0.345400
# 23     219.662576     23.673487         5.620314        0.730059
# 24      48.452263      1.176047         1.476686        0.022184
# 25      94.925425      1.162154         2.797119        0.031005
# 26     152.646675     13.868467         5.636046        1.624059
# 27     213.442339     10.960712         6.155756        0.755581
# 28      51.619123      3.516111         1.737886        0.108391
# 29     110.322528      3.706861         3.531168        0.954450
# 30     171.152905      4.480885         5.318078        1.478227
# 31     239.747920      9.160021         7.984061        1.334966
# 32      68.043532     10.971021         2.499674        0.537745
# 33     146.259686     18.313873         4.483393        0.971618
# 34     167.293286      6.639323         4.927898        0.620261
# 35     208.886876      8.912207         6.282004        1.314056
# 36      49.960453      0.255617         1.720413        0.126285
# 37      99.193014      2.405214         2.839562        0.100858
# 38     166.521348     12.381683         5.313328        0.800825
# 39     201.601861     48.702911         4.207522        1.316181
#
#    param_classifier__learning_rate param_classifier__n_estimators  \
# 0                           0.0001                             50
# 1                           0.0001                            100
# 2                           0.0001                            150
# 3                           0.0001                            200
# 4                           0.1112                             50
# 5                           0.1112                            100
# 6                           0.1112                            150
# 7                           0.1112                            200
# 8                           0.2223                             50
# 9                           0.2223                            100
# 10                          0.2223                            150
# 11                          0.2223                            200
# 12                          0.3334                             50
# 13                          0.3334                            100
# 14                          0.3334                            150
# 15                          0.3334                            200
# 16                          0.4445                             50
# 17                          0.4445                            100
# 18                          0.4445                            150
# 19                          0.4445                            200
# 20                          0.5556                             50
# 21                          0.5556                            100
# 22                          0.5556                            150
# 23                          0.5556                            200
# 24                          0.6667                             50
# 25                          0.6667                            100
# 26                          0.6667                            150
# 27                          0.6667                            200
# 28                          0.7778                             50
# 29                          0.7778                            100
# 30                          0.7778                            150
# 31                          0.7778                            200
# 32                          0.8889                             50
# 33                          0.8889                            100
# 34                          0.8889                            150
# 35                          0.8889                            200
# 36                             1.0                             50
# 37                             1.0                            100
# 38                             1.0                            150
# 39                             1.0                            200
#
#                                                params  split0_test_score  \
# 0   {'classifier__learning_rate': 0.0001, 'classif...           0.689251
# 1   {'classifier__learning_rate': 0.0001, 'classif...           0.689251
# 2   {'classifier__learning_rate': 0.0001, 'classif...           0.689251
# 3   {'classifier__learning_rate': 0.0001, 'classif...           0.689251
# 4   {'classifier__learning_rate': 0.11120000000000...           0.827046
# 5   {'classifier__learning_rate': 0.11120000000000...           0.842520
# 6   {'classifier__learning_rate': 0.11120000000000...           0.849478
# 7   {'classifier__learning_rate': 0.11120000000000...           0.853324
# 8   {'classifier__learning_rate': 0.2223, 'classif...           0.843161
# 9   {'classifier__learning_rate': 0.2223, 'classif...           0.853873
# 10  {'classifier__learning_rate': 0.2223, 'classif...           0.856620
# 11  {'classifier__learning_rate': 0.2223, 'classif...           0.859000
# 12  {'classifier__learning_rate': 0.33340000000000...           0.850943
# 13  {'classifier__learning_rate': 0.33340000000000...           0.856986
# 14  {'classifier__learning_rate': 0.33340000000000...           0.859275
# 15  {'classifier__learning_rate': 0.33340000000000...           0.858268
# 16  {'classifier__learning_rate': 0.4445, 'classif...           0.851767
# 17  {'classifier__learning_rate': 0.4445, 'classif...           0.859092
# 18  {'classifier__learning_rate': 0.4445, 'classif...           0.859641
# 19  {'classifier__learning_rate': 0.4445, 'classif...           0.861198
# 20  {'classifier__learning_rate': 0.5556, 'classif...           0.854605
# 21  {'classifier__learning_rate': 0.5556, 'classif...           0.859916
# 22  {'classifier__learning_rate': 0.5556, 'classif...           0.860282
# 23  {'classifier__learning_rate': 0.5556, 'classif...           0.862479
# 24  {'classifier__learning_rate': 0.66670000000000...           0.852316
# 25  {'classifier__learning_rate': 0.66670000000000...           0.859733
# 26  {'classifier__learning_rate': 0.66670000000000...           0.862846
# 27  {'classifier__learning_rate': 0.66670000000000...           0.864127
# 28  {'classifier__learning_rate': 0.7778, 'classif...           0.854239
# 29  {'classifier__learning_rate': 0.7778, 'classif...           0.860374
# 30  {'classifier__learning_rate': 0.7778, 'classif...           0.862479
# 31  {'classifier__learning_rate': 0.7778, 'classif...           0.864402
# 32  {'classifier__learning_rate': 0.8889, 'classif...           0.852042
# 33  {'classifier__learning_rate': 0.8889, 'classif...           0.859550
# 34  {'classifier__learning_rate': 0.8889, 'classif...           0.862022
# 35  {'classifier__learning_rate': 0.8889, 'classif...           0.865318
# 36  {'classifier__learning_rate': 1.0, 'classifier...           0.856528
# 37  {'classifier__learning_rate': 1.0, 'classifier...           0.861838
# 38  {'classifier__learning_rate': 1.0, 'classifier...           0.863578
# 39  {'classifier__learning_rate': 1.0, 'classifier...           0.866325
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0
mean_scores = adaboost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = adaboost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[adaboost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]

#one_stand_error_data_frame = adaboost_pipe_cv.cv_results_[adaboost_pipe_cv.cv_results_["mean_test_score"] >= (mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 27     213.442339     10.960712         6.155756        0.755581
#
#    param_classifier__learning_rate param_classifier__n_estimators  \
# 27                          0.6667                            200
#
#                                                params  split0_test_score  \
# 27  {'classifier__learning_rate': 0.66670000000000...           0.864127
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 27           0.867973           0.858804           0.860635
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 27           0.859079         0.862124        0.003485                4

# %%
clf.set_params(classifier__learning_rate= 0.6667, classifier__n_estimators = 200)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  AdaBoostClassifier(learning_rate=0.6667, n_estimators=200,
#                                     random_state=10))])

# %%
clf.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  AdaBoostClassifier(learning_rate=0.6667, n_estimators=200,
#                                     random_state=10))])

# %% [markdown]
# ### Export the predictions to .csv

# %%
Adaboost_200_067 = test_df[["id"]]
y_test_pred = clf.predict(test_df.drop("id",axis = 1))
print(y_test_pred)
Adaboost_200_067["high_income"] = y_test_pred
Adaboost_200_067
# Out:
# [0 0 0 ... 0 0 1]
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_17509/471037916.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Adaboost_200_067["high_income"] = y_test_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            0
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
Adaboost_200_067.to_csv("Predictions/Adaboost_200_067.csv",index = False, header=True)

# %% [markdown]
# ## Second try with AdaBoost

# %%
hyper_param = {"classifier__n_estimators":np.arange(300,600,100),
              "classifier__learning_rate":[1]}
adaboost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
adaboost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'fam_under_18',
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         AdaBoostClassifier(learning_rate=0.6667,
#                                                            n_estimators=200,
#                                                            random_state=10))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [1],
#                          'classifier__n_estimators': array([300, 400, 500])},
#              scoring='accuracy', verbose=1)

# %%
cv_res = pd.DataFrame(adaboost_pipe_cv.cv_results_)
cv_res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     412.378320     25.070280         9.939529        0.223766
# 1     470.399785      6.237278        12.762686        0.596042
# 2     505.648733     71.390799        11.562076        3.196590
#
#   param_classifier__learning_rate param_classifier__n_estimators  \
# 0                               1                            300
# 1                               1                            400
# 2                               1                            500
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 1, 'classifier__...           0.867973
# 1  {'classifier__learning_rate': 1, 'classifier__...           0.869346
# 2  {'classifier__learning_rate': 1, 'classifier__...           0.869987
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.869529           0.865214           0.863291           0.861643
# 1           0.869896           0.865672           0.863016           0.863657
# 2           0.870262           0.865214           0.863382           0.864756
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.865530        0.002905                3
# 1         0.866317        0.002841                2
# 2         0.866720        0.002845                1

# %%
#Since all of the models are getting better let's take the best one and not the one standard error 
clf.set_params(classifier__learning_rate= 1, classifier__n_estimators = 500)
clf.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  AdaBoostClassifier(learning_rate=1, n_estimators=500,
#                                     random_state=10))])

# %% [markdown]
# ### Export the predictions to .csv

# %%
Adaboost_500_1 = test_df[["id"]]
y_test_pred = clf.predict(test_df.drop("id",axis = 1))
print(y_test_pred)
Adaboost_500_1["high_income"] = y_test_pred
Adaboost_500_1
# Out:
# [0 0 0 ... 0 0 1]
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_17509/2762351658.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Adaboost_500_1["high_income"] = y_test_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
Adaboost_500_1.to_csv("Predictions/Adaboost_500_1.csv",index = False, header=True)

# %% [markdown]
# ## Third try with AdaBoost

# %%
hyper_param = {"classifier__n_estimators":np.arange(50,250,50),
              "classifier__learning_rate":[0.5]}
adaboost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
adaboost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'citizenship',
#                                                                           'union_member',
#                                                                           'fam_under_18',
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         AdaBoostClassifier(random_state=10))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.5],
#                          'classifier__n_estimators': array([ 50, 100, 150, 200])},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(adaboost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      79.411217      2.486568         2.405650        0.921770
# 1     144.888018     28.071966         3.324838        0.829401
# 2     162.587193      7.306207         4.739735        0.503395
# 3     173.102836     20.878265         4.032979        1.182651
#
#   param_classifier__learning_rate param_classifier__n_estimators  \
# 0                             0.5                             50
# 1                             0.5                            100
# 2                             0.5                            150
# 3                             0.5                            200
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.5, 'classifier...           0.853415
# 1  {'classifier__learning_rate': 0.5, 'classifier...           0.857993
# 2  {'classifier__learning_rate': 0.5, 'classifier...           0.860282
# 3  {'classifier__learning_rate': 0.5, 'classifier...           0.861930
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.854148           0.849190           0.851021           0.851479
# 1           0.860374           0.854684           0.858529           0.856057
# 2           0.863761           0.856973           0.860819           0.856881
# 3           0.865501           0.857248           0.861093           0.858255
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.851850        0.001768                4
# 1         0.857527        0.001978                3
# 2         0.859743        0.002587                2
# 3         0.860805        0.002918                1

# %% [markdown]
# **COMMENTS**
#
# There is no improvement compared to the previous models, so we will not export any models.

# %% [markdown]
# # GradientBoostingClassifier

# %% [markdown]
# ## First try with GradientBoostingClassifier

# %%
numeric_transformer = Pipeline(
    steps=[("imputer_num", SimpleImputer(strategy="mean")),
           ("scaler", StandardScaler())]
)

categorical_transformer = Pipeline(
    steps=[("imputer_cat", SimpleImputer(strategy="constant", fill_value="Missing")),
           
           ("encoder" , OneHotEncoder(handle_unknown="ignore", sparse=False))]
)



preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", GradientBoostingClassifier(max_depth = 2, n_estimators = 100, learning_rate = .1, random_state=1))]
)


set_config(display="diagram")
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'mig_move_reg', 'hs_college',
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(max_depth=2, random_state=1))])

# %%
hyper_param = {"classifier__n_estimators":[50,100,150],
              "classifier__learning_rate":[0.1, 0.5]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'union_member',
#                                                                           'fam_under_18',
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.1, 0.5],
#                          'classifier__n_estimators': [50, 100, 150]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     105.724015      2.751150         0.348994        0.057167
# 1     200.124028      8.346743         0.495751        0.069842
# 2     330.605717      3.401773         0.540317        0.043409
# 3     111.338329      1.624213         0.459856        0.037917
# 4    1416.778972    599.004222         0.474014        0.041373
# 5     274.813180     70.381091         0.426003        0.168658
#
#   param_classifier__learning_rate param_classifier__n_estimators  \
# 0                             0.1                             50
# 1                             0.1                            100
# 2                             0.1                            150
# 3                             0.5                             50
# 4                             0.5                            100
# 5                             0.5                            150
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.1, 'classifier...           0.843435
# 1  {'classifier__learning_rate': 0.1, 'classifier...           0.853964
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.859366
# 3  {'classifier__learning_rate': 0.5, 'classifier...           0.864494
# 4  {'classifier__learning_rate': 0.5, 'classifier...           0.869804
# 5  {'classifier__learning_rate': 0.5, 'classifier...           0.870811
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.846640           0.843238           0.843329           0.848182
# 1           0.856345           0.853860           0.853585           0.857064
# 2           0.860099           0.858255           0.857797           0.859170
# 3           0.863578           0.861185           0.862101           0.858896
# 4           0.868705           0.864848           0.863199           0.863840
# 5           0.869896           0.865672           0.866221           0.866862
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.844965        0.002057                6
# 1         0.854964        0.001445                5
# 2         0.858937        0.000819                4
# 3         0.862051        0.001950                3
# 4         0.866079        0.002668                2
# 5         0.867892        0.002065                1

# %%
#0.5 seems to be a good learning rate
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]

#one_stand_error_data_frame = adaboost_pipe_cv.cv_results_[adaboost_pipe_cv.cv_results_["mean_test_score"] >= (mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5      274.81318     70.381091         0.426003        0.168658
#
#   param_classifier__learning_rate param_classifier__n_estimators  \
# 5                             0.5                            150
#
#                                               params  split0_test_score  \
# 5  {'classifier__learning_rate': 0.5, 'classifier...           0.870811
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 5           0.869896           0.865672           0.866221           0.866862
#
#    mean_test_score  std_test_score  rank_test_score
# 5         0.867892        0.002065                1

# %%
hyper_param = {"classifier__n_estimators":[120,130,140],
              "classifier__learning_rate":[ 0.5, 0.6]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'union_member',
#                                                                           'fam_under_18',
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.5, 0.6],
#                          'classifier__n_estimators': [120, 130, 140]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     245.181538      5.891427         0.468088        0.095770
# 1     274.644185      1.895358         0.657985        0.116856
# 2     302.477921      4.033478         0.678403        0.217983
# 3     235.549836     14.970818         0.421287        0.076563
# 4     263.265813     14.403825         0.560882        0.011308
# 5     260.758423     62.990416         0.416216        0.154734
#
#   param_classifier__learning_rate param_classifier__n_estimators  \
# 0                             0.5                            120
# 1                             0.5                            130
# 2                             0.5                            140
# 3                             0.6                            120
# 4                             0.6                            130
# 5                             0.6                            140
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.5, 'classifier...           0.869621
# 1  {'classifier__learning_rate': 0.5, 'classifier...           0.869621
# 2  {'classifier__learning_rate': 0.5, 'classifier...           0.869346
# 3  {'classifier__learning_rate': 0.6, 'classifier...           0.868797
# 4  {'classifier__learning_rate': 0.6, 'classifier...           0.868064
# 5  {'classifier__learning_rate': 0.6, 'classifier...           0.867973
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.869346           0.865397           0.865946           0.865489
# 1           0.869987           0.864664           0.866404           0.865397
# 2           0.869804           0.865672           0.866954           0.865763
# 3           0.871727           0.864939           0.865855           0.867045
# 4           0.872276           0.865214           0.865214           0.867137
# 5           0.872642           0.865122           0.866404           0.867228
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.867160        0.001908                6
# 1         0.867215        0.002188                5
# 2         0.867508        0.001754                4
# 3         0.867673        0.002403                2
# 4         0.867581        0.002595                3
# 5         0.867874        0.002565                1

# %%
clf.set_params(classifier__learning_rate = 0.5, classifier__n_estimators = 150)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.5, max_depth=2,
#                                             n_estimators=150,
#                                             random_state=1))])

# %%
clf.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.5, max_depth=2,
#                                             n_estimators=150,
#                                             random_state=1))])

# %% [markdown]
# ### Export the predictions to .csv

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
GB_tree_150_0_5_max_depth_2 = test_df[["id"]]
GB_tree_150_0_5_max_depth_2["high_income"] = y_pred
GB_tree_150_0_5_max_depth_2
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_1525/2913295665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_150_0_5_max_depth_2["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_150_0_5_max_depth_2.to_csv("Predictions/GB_tree_150_0_5_max_depth_2.csv",index = False, header=True)

# %% [markdown]
# ## Second try with GradientBoostingClassifier

# %%
hyper_param = {"classifier__n_estimators":[600],
              "classifier__learning_rate":[0.05]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=10, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'wee...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(learning_rate=0.5,
#                                                                    max_depth=2,
#                                                                    n_estimators=150,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.05],
#                          'classifier__n_estimators': [600]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0    1354.983562    276.765642         0.464447        0.110556
#
#   param_classifier__learning_rate param_classifier__n_estimators  \
# 0                            0.05                            600
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.05, 'classifie...           0.862663
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.865409           0.868888           0.863578           0.864127
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.860099           0.862846           0.863736           0.862271
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.863004         0.863662        0.002175                1

# %%
clf.set_params(classifier__learning_rate = 0.05, classifier__n_estimators = 600)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.05, max_depth=2,
#                                             n_estimators=600,
#                                             random_state=1))])

# %%
clf.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.05, max_depth=2,
#                                             n_estimators=600,
#                                             random_state=1))])

# %% [markdown]
# ### Export the predictions to .csv

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
GB_tree_600_0_05_max_depth_2 = test_df[["id"]]
GB_tree_600_0_05_max_depth_2["high_income"] = y_pred
GB_tree_600_0_05_max_depth_2
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_1525/112452500.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_600_0_05_max_depth_2["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_600_0_05_max_depth_2.to_csv("Predictions/GB_tree_600_0_05_max_depth_2.csv",index = False, header=True)
#0.861 %

# %% [markdown]
# ## Third try with GradientBoostingClassifier

# %%
# Could think of increasing the max depth of the tree, restricting the nb of features 21 for the RF
# generally low learning rate more tree but this is very expensive ! 0.1 is usually a good learning rate

# %%
# Trying smaller tree but with a higher depth --> Learning rate 0.1 and 30 to 50.

# %%
hyper_param = {"classifier__n_estimators":[30,40,50],
              "classifier__learning_rate":[0.1],
              "classifier__max_depth":[8]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'fam_under_18',
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.1],
#                          'classifier__max_depth': [8],
#                          'classifier__n_estimators': [30, 40, 50]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     226.679570      7.807365         0.423266        0.078332
# 1     324.119853      1.077055         0.506118        0.056663
# 2     347.584139     47.128289         0.481702        0.117429
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                             0.1                           8
# 1                             0.1                           8
# 2                             0.1                           8
#
#   param_classifier__n_estimators  \
# 0                             30
# 1                             40
# 2                             50
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.1, 'classifier...           0.862754
# 1  {'classifier__learning_rate': 0.1, 'classifier...           0.864036
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.866325
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.865226           0.859995           0.861734           0.863566
# 1           0.866416           0.863291           0.863016           0.864390
# 2           0.867149           0.865122           0.863749           0.866862
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.862655        0.001754                3
# 1         0.864230        0.001200                2
# 2         0.865841        0.001255                1

# %%
#0.5 seems to be a good learning rate
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]

#one_stand_error_data_frame = adaboost_pipe_cv.cv_results_[adaboost_pipe_cv.cv_results_["mean_test_score"] >= (mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2     347.584139     47.128289         0.481702        0.117429
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 2                             0.1                           8
#
#   param_classifier__n_estimators  \
# 2                             50
#
#                                               params  split0_test_score  \
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.866325
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 2           0.867149           0.865122           0.863749           0.866862
#
#    mean_test_score  std_test_score  rank_test_score
# 2         0.865841        0.001255                1

# %% [markdown]
# ## Further trials for GradientBoostingClassifier

# %%
numeric_transformer = Pipeline(
    steps=[("imputer_num", SimpleImputer(strategy="mean")),
           ("scaler", StandardScaler())]
)

categorical_transformer = Pipeline(
    steps=[("imputer_cat", SimpleImputer(strategy="constant", fill_value="Missing")),
           
           ("encoder" , OneHotEncoder(handle_unknown="ignore", sparse=False))]
)



preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", GradientBoostingClassifier(max_depth = 2, n_estimators = 100, learning_rate = .1, random_state=10, verbose=1))]
)


set_config(display="diagram")
clf

hyper_param = {"classifier__n_estimators":[50],
              "classifier__learning_rate":[0.1,0.09],
              "classifier__max_depth":[8,10,12]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_32146/245585618.py in <module>
# ----> 1 numeric_transformer = Pipeline(
#       2     steps=[("imputer_num", SimpleImputer(strategy="mean")),
#       3            ("scaler", StandardScaler())]
#       4 )
#       5
#
# NameError: name 'Pipeline' is not defined

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
#       Iter       Train Loss   Remaining Time
#          1           1.1388            3.10m
#          2           1.0629            3.02m
#          3           1.0012            3.28m
#          4           0.9496            3.16m
#          5           0.9062            3.08m
#          6           0.8688            3.02m
#          7           0.8364            2.93m
#          8           0.8081            2.84m
#          9           0.7833            2.76m
#         10           0.7612            2.67m
#         20           0.6281            1.89m
#       Iter       Train Loss   Remaining Time
#          1           1.1378            6.44m
#          2           1.0615            5.99m
#          3           0.9993            5.94m
#          4           0.9476            5.84m
#          5           0.9037            5.82m
#          6           0.8665            5.57m
#          7           0.8341            5.35m
#          8           0.8052            5.17m
#          9           0.7799            5.02m
#         10           0.7578            4.86m
#         20           0.6196            3.55m
#         30           0.5560            2.37m
#         40           0.5188            1.19m
#         50           0.4944            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.
0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1460            5.30m
#          2           1.0759            5.24m
#          3           1.0171            5.00m
#          4           0.9674            4.92m
#          5           0.9249            4.84m
#          6           0.8877            4.78m
#          7           0.8546            4.62m
#          8           0.8265            4.56m
#          9           0.8013            4.51m
#         10           0.7789            4.41m
#         20           0.6390            3.49m
#         30           0.5727            2.29m
#         40           0.5346            1.15m
#         50           0.5063            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1491            5.01m
#          2           1.0785            4.82m
#          3           1.0199            4.88m
#          4           0.9701            4.85m
#          5           0.9276            4.81m
#          6           0.8908            4.75m
#          7           0.8583            4.69m
#          8           0.8293            4.59m
#          9           0.8037            4.49m
#         10           0.7814            4.44m
#         20           0.6418            3.34m
#         30           0.5753            2.27m
#         40           0.5355            1.16m
#         50           0.5091            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1396            7.11m
#          2           1.0635            6.53m
#          3           1.0002            6.13m
#          4           0.9464            5.84m
#          5           0.9005            5.80m
#          6           0.8598            5.67m
#          7           0.8243            5.57m
#          8           0.7927            5.33m
#          9           0.7651            5.22m
#         10           0.7394            5.12m
#         20           0.5853            4.20m
#         30           0.5053            3.05m
#         40           0.4576            1.53m
#         50           0.4265            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1310            8.46m
#          2           1.0485            7.63m
#          3           0.9801            7.28m
#          4           0.9214            7.22m
#          5           0.8711            6.89m
#          6           0.8264            6.74m
#          7           0.7871            6.47m
#          8           0.7528            6.26m
#          9           0.7212            6.08m
#         10           0.6948            5.92m
#         20           0.5161            4.52m
#         30           0.4275            3.06m
#         40           0.3659            1.55m
#         50           0.3274            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1334            7.06m
#          2           1.0505            6.59m
#          3           0.9816            6.59m
#          4           0.9223            6.42m
#          5           0.8717            6.37m
#          6           0.8268            6.14m
#          7           0.7873            5.83m
#          8           0.7523            5.57m
#          9           0.7207            5.32m
#         10           0.6920            5.08m
#         20           0.5157            3.10m
#         30           0.4263            1.87m
#         40           0.3662           53.79s
#         50           0.3243            0.00s

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     365.263924      1.796232         0.480564        0.110468
# 1     431.070508      7.212868         0.553187        0.069492
# 2     484.622157      3.546580         0.758840        0.196375
# 3     357.204815      3.114612         0.636524        0.087125
# 4     446.592846     16.319818         0.717179        0.125965
# 5     384.663077     88.757744         0.431733        0.146597
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                             0.1                           8
# 1                             0.1                          10
# 2                             0.1                          12
# 3                            0.09                           8
# 4                            0.09                          10
# 5                            0.09                          12
#
#   param_classifier__n_estimators  \
# 0                             50
# 1                             50
# 2                             50
# 3                             50
# 4                             50
# 5                             50
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.1, 'classifier...           0.864219
# 1  {'classifier__learning_rate': 0.1, 'classifier...           0.864219
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.863303
# 3  {'classifier__learning_rate': 0.09, 'classifie...           0.865318
# 4  {'classifier__learning_rate': 0.09, 'classifie...           0.864585
# 5  {'classifier__learning_rate': 0.09, 'classifie...           0.863395
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.867424           0.863566           0.866404           0.865946
# 1           0.867240           0.864664           0.864207           0.865763
# 2           0.867424           0.864115           0.865214           0.865672
# 3           0.868797           0.862467           0.865305           0.864939
# 4           0.867424           0.865672           0.864207           0.865031
# 5           0.866600           0.861093           0.862925           0.865214
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.865512        0.001421                1
# 1         0.865219        0.001159                4
# 2         0.865145        0.001409                5
# 3         0.865365        0.002018                3
# 4         0.865384        0.001131                2
# 5         0.863845        0.001902                6

# %%
# It seems that a max depth of 8 perform better. and with a learning rate of 0.1 on a model with only 50 estimators

# %%
hyper_param = {"classifier__n_estimators":[50],
              "classifier__learning_rate":[0.1],
              "classifier__max_depth":[1,4,6]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#       Iter       Train Loss   Remaining Time
#          1           1.1461            2.49m
#          2           1.0759            2.52m
#          3           1.0185            2.50m
#          4           0.9702            2.42m
#          5           0.9299            2.35m
#          6           0.8950            2.32m
#          7           0.8653            2.28m
#          8           0.8392            2.23m
#          9           0.8168            2.18m
#         10           0.7960            2.13m
#         20           0.6764            1.60m
#         30           0.6239            1.07m
#         40           0.5931           31.49s
#       Iter       Train Loss   Remaining Time
#          1           1.1987           52.48s
#          2           1.1680           53.33s
#          3           1.1424           52.65s
#          4           1.1176           51.71s
#          5           1.0970           50.38s
#          6           1.0786           49.12s
#          7           1.0638           47.95s
#          8           1.0473           46.70s
#          9           1.0335           45.31s
#         10           1.0219           44.22s
#         20           0.9341           32.96s
#         30           0.8784           22.10s
#         40           0.8381           11.01s
#         50           0.8084            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1570            3.83m
#          2           1.0938            3.64m
#          3           1.0420            3.58m
#          4           0.9984            3.40m
#          5           0.9602            3.30m
#          6           0.9281            3.23m
#          7           0.8999            3.12m
#          8           0.8763            3.07m
#          9           0.8550            2.97m
#         10           0.8357            2.91m
#         20           0.7252            2.17m
#         30           0.6761            1.45m
#         40           0.6469           44.02s
#         50           0.6260            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1448            5.48m
#          2           1.0744            5.22m
#          3           1.0170            5.16m
#          4           0.9690            5.03m
#          5           0.9286            4.92m
#          6           0.8941            4.75m
#          7           0.8642            4.59m
#          8           0.8385            4.59m
#          9           0.8159            4.45m
#         10           0.7959            4.30m
#         20           0.6746            3.27m
#         30           0.6212            2.17m
#         40           0.5905            1.08m
#         50           0.5704            0.00s
#         50           0.5736            0.00s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=10,
#                                                                    verbose=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.1],
#                          'classifier__max_depth': [1, 4, 6],
#                          'classifier__n_estimators': [50]},
#              scoring='accuracy', verbose=1)
#       Iter       Train Loss   Remaining Time
#          1           1.1958           52.02s
#          2           1.1650           53.31s
#          3           1.1397           52.52s
#          4           1.1152           51.40s
#          5           1.0942           49.89s
#          6           1.0760           48.68s
#          7           1.0614           47.54s
#          8           1.0453           46.33s
#          9           1.0316           45.02s
#         10           1.0198           43.92s
#         20           0.9318           32.61s
#         30           0.8763           21.94s
#         40           0.8358           10.95s
#         50           0.8051            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1984           47.19s
#          2           1.1675           52.47s
#          3           1.1421           53.11s
#          4           1.1175           53.62s
#          5           1.0964           51.81s
#          6           1.0782           50.94s
#          7           1.0635           49.70s
#          8           1.0474           48.06s
#          9           1.0337           46.83s
#         10           1.0221           46.13s
#         20           0.9345           33.89s
#         30           0.8792           22.57s
#         40           0.8384           11.30s
#         50           0.8083            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.
0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1444            5.40m
#          2           1.0742            5.19m
#          3           1.0163            5.12m
#          4           0.9685            4.90m
#          5           0.9276            4.88m
#          6           0.8926            4.68m
#          7           0.8625            4.53m
#          8           0.8362            4.48m
#          9           0.8133            4.43m
#         10           0.7935            4.26m
#         20           0.6721            3.25m
#         30           0.6186            2.16m
#         40           0.5885            1.07m
#         50           0.5672            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1472            3.71m
#          2           1.0765            3.47m
#          3           1.0190            3.40m
#          4           0.9706            3.35m
#          5           0.9303            3.24m
#          6           0.8952            3.18m
#          7           0.8652            3.14m
#          8           0.8388            3.10m
#          9           0.8161            3.01m
#         10           0.7957            2.83m
#         20           0.6737            1.80m
#         30           0.6201            1.09m
#         40           0.5875           30.85s
#         50           0.5668            0.00s

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      56.718018      1.403295         0.343789        0.062519
# 1     223.950851      0.601200         0.676708        0.172143
# 2     264.835851     71.350420         0.438767        0.189936
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                             0.1                           1
# 1                             0.1                           4
# 2                             0.1                           6
#
#   param_classifier__n_estimators  \
# 0                             50
# 1                             50
# 2                             50
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.1, 'classifier...           0.811939
# 1  {'classifier__learning_rate': 0.1, 'classifier...           0.858726
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.864311
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.816334           0.816409           0.817233           0.817782
# 1           0.860557           0.859811           0.857888           0.857888
# 2           0.865684           0.863108           0.861460           0.864939
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.815939        0.002071                3
# 1         0.858974        0.001061                2
# 2         0.863900        0.001484                1

# %%
# It seems that a depth of 8 it the best for boosting --> now we need to find the best nb of tree.

# %%
hyper_param = {"classifier__n_estimators":[60,70,80,90,100],
              "classifier__learning_rate":[0.1],
              "classifier__max_depth":[8]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#       Iter       Train Loss   Remaining Time
#          1           1.1369            7.84m
#          2           1.0612            7.54m
#          3           0.9988            7.44m
#          4           0.9466            7.28m
#          5           0.9028            7.14m
#          6           0.8647            6.96m
#          7           0.8322            6.72m
#          8           0.8039            6.65m
#          9           0.7787            6.54m
#         10           0.7563            6.43m
#         20           0.6206            4.97m
#         30           0.5583            3.74m
#         40           0.5204            2.50m
#         50           0.4957            1.24m
#         60           0.4777            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1369            5.87m
#          2           1.0612            6.66m
#          3           0.9988            7.18m
#          4           0.9466            7.35m
#          5           0.9028            7.61m
#          6           0.8647            7.45m
#          7           0.8322            7.33m
#          8           0.8039            7.38m
#          9           0.7787            7.21m
#         10           0.7563            7.09m
#         20           0.6206            5.82m
#         30           0.5583            4.66m
#         40           0.5204            3.53m
#         50           0.4957            2.45m
#         60           0.4777            1.25m
#         70           0.4646            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1395            7.16m
#          2           1.0637            7.71m
#          3           1.0011            8.04m
#          4           0.9492            8.17m
#          5           0.9047            8.21m
#          6           0.8667            7.98m
#          7           0.8340            7.75m
#          8           0.8056            7.59m
#          9           0.7807            7.35m
#         10           0.7583            7.23m
#         20           0.6230            6.28m
#         30           0.5579            4.93m
#         40           0.5196            3.75m
#         50           0.4943            2.55m
#         60           0.4765            1.28m
#         70           0.4597            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.
0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1371           14.10m
#          2           1.0610           13.56m
#          3           0.9991           13.48m
#          4           0.9474           13.32m
#          5           0.9039           13.17m
#          6           0.8664           12.94m
#          7           0.8340           12.95m
#          8           0.8059           12.86m
#          9           0.7808           12.56m
#         10           0.7589           12.36m
#         20           0.6216           11.01m
#         30           0.5599            9.48m
#         40           0.5240            7.84m
#         50           0.4999            5.99m
#         60           0.4823            4.48m
#         70           0.4651            2.97m
#         80           0.4550            1.48m
#         90           0.4453            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1369           13.29m
#          2           1.0612           12.86m
#          3           0.9988           12.68m
#          4           0.9466           12.72m
#          5           0.9028           12.59m
#          6           0.8647           12.24m
#          7           0.8322           11.99m
#          8           0.8039           12.00m
#          9           0.7787           11.95m
#         10           0.7563           11.50m
#         20           0.6206           10.26m
#         30           0.5583            9.17m
#         40           0.5204            7.93m
#         50           0.4957            6.70m
#         60           0.4777            5.44m
#         70           0.4646            4.13m
#         80           0.4525            2.78m
#         90           0.4434            1.40m
#        100           0.4321            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1395           13.65m
#          2           1.0637           13.22m
#          3           1.0011           13.24m
#          4           0.9492           13.14m
#          5           0.9047           13.06m
#          6           0.8667           12.93m
#          7           0.8340           12.50m
#          8           0.8056           12.39m
#          9           0.7807           12.28m
#         10           0.7583           11.78m
#         20           0.6230            9.15m
#         30           0.5579            6.87m
#         40           0.5196            5.22m
#         50           0.4943            4.06m
#         60           0.4765            3.12m
#         70           0.4597            2.27m
#         80           0.4479            1.48m
#         90           0.4373           43.43s
#        100           0.4279            0.00s
#         70           0.4794            2.36m
#         80           0.4680            1.57m
#         90           0.4590           47.88s
#        100           0.4517            0.00s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=10,
#                                                                    verbose=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.1],
#                          'classifier__max_depth': [8],
#                          'classifier__n_estimators': [60, 70, 80, 90, 100]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     455.206674      1.011995         0.557819        0.111942
# 1     534.954638      4.306399         0.694264        0.055594
# 2     621.534629     15.885423         0.829861        0.130433
# 3     768.256876     18.679574         0.759287        0.090406
# 4     748.312546    162.911223         0.582443        0.177996
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                             0.1                           8
# 1                             0.1                           8
# 2                             0.1                           8
# 3                             0.1                           8
# 4                             0.1                           8
#
#   param_classifier__n_estimators  \
# 0                             60
# 1                             70
# 2                             80
# 3                             90
# 4                            100
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.1, 'classifier...           0.865501
# 1  {'classifier__learning_rate': 0.1, 'classifier...           0.865867
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.866233
# 3  {'classifier__learning_rate': 0.1, 'classifier...           0.866508
# 4  {'classifier__learning_rate': 0.1, 'classifier...           0.866691
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.868339           0.865763           0.866313           0.867320
# 1           0.870445           0.866221           0.866496           0.866496
# 2           0.871452           0.867595           0.867228           0.866038
# 3           0.871269           0.868510           0.867869           0.866313
# 4           0.871910           0.868510           0.868327           0.866954
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.866647        0.001051                5
# 1         0.867105        0.001686                4
# 2         0.867709        0.001961                3
# 3         0.868094        0.001788                2
# 4         0.868478        0.001861                1

# %%
#0.1 LR
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2     621.534629     15.885423         0.829861        0.130433
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 2                             0.1                           8
#
#   param_classifier__n_estimators  \
# 2                             80
#
#                                               params  split0_test_score  \
# 2  {'classifier__learning_rate': 0.1, 'classifier...           0.866233
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 2           0.871452           0.867595           0.867228           0.866038
#
#    mean_test_score  std_test_score  rank_test_score
# 2         0.867709        0.001961                3

# %%
clf.set_params(classifier__learning_rate = 0.1, classifier__n_estimators = 80, classifier__max_depth = 8)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(max_depth=8, n_estimators=80,
#                                             random_state=10, verbose=1))])

# %%
clf.fit(X,y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.1388            6.05m
#          2           1.0629            5.83m
#          3           1.0012            5.74m
#          4           0.9496            5.67m
#          5           0.9062            5.55m
#          6           0.8688            5.36m
#          7           0.8364            5.07m
#          8           0.8081            5.05m
#          9           0.7833            5.04m
#         10           0.7612            4.96m
#         20           0.6281            4.34m
#         30           0.5677            3.68m
#         40           0.5314            2.91m
#         50           0.5086            2.20m
#         60           0.4929            1.47m
#         70           0.4794           43.96s
#         80           0.4680            0.00s
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(max_depth=8, n_estimators=80,
#                                             random_state=10, verbose=1))])

# %% [markdown]
# ### Export the predictions to .csv

# %%
#one standard error rule 
y_pred = clf.predict(test_df.drop("id",axis = 1))
GB_tree_80_LR01_max_depth_8 = test_df[["id"]]
GB_tree_80_LR01_max_depth_8["high_income"] = y_pred
GB_tree_80_LR01_max_depth_8
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_7054/3403539419.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_80_LR01_max_depth_8["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            0
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            1
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_80_LR01_max_depth_8.to_csv("Predictions/GB_tree_80_LR01_max_depth_8.csv",index = False, header=True)

# %%
clf.set_params(classifier__learning_rate = 0.1, classifier__n_estimators = 100, classifier__max_depth = 8)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(max_depth=8, random_state=10,
#                                             verbose=1))])

# %%
clf.fit(X,y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.1388            7.23m
#          2           1.0629            7.04m
#          3           1.0012            6.75m
#          4           0.9496            6.64m
#          5           0.9062            6.62m
#          6           0.8688            6.57m
#          7           0.8364            6.57m
#          8           0.8081            6.48m
#          9           0.7833            6.34m
#         10           0.7612            6.09m
#         20           0.6281            5.77m
#         30           0.5677            5.18m
#         40           0.5314            4.47m
#         50           0.5086            3.82m
#         60           0.4929            3.09m
#         70           0.4794            2.31m
#         80           0.4680            1.54m
#         90           0.4590            1.23m
#        100           0.4517            0.00s
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(max_depth=8, random_state=10,
#                                             verbose=1))])

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
GB_tree_100_LR01_max_depth_8 = test_df[["id"]]
GB_tree_100_LR01_max_depth_8["high_income"] = y_pred
GB_tree_100_LR01_max_depth_8
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_13391/496441298.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_100_LR01_max_depth_8["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            0
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            1
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_100_LR01_max_depth_8.to_csv("Predictions/GB_tree_100_LR01_max_depth_8.csv",index = False, header=True)

# %% [markdown]
# # Deeper trials

# %% [markdown]
# ## First try with M1 Pro

# %%
hyper_param = {"classifier__n_estimators":[100, 150],
              "classifier__learning_rate":[0.15, 0.2],
              "classifier__max_depth":[2, 3]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.15, 0.2],
#                          'classifier__max_depth': [2, 3],
#                          'classifier__n_estimators': [100, 150]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      39.419275      0.133196         0.133319        0.012459
# 1      58.158957      0.325037         0.152689        0.012639
# 2      56.290325      0.099685         0.162464        0.035377
# 3      84.878327      0.340935         0.166893        0.030195
# 4      38.712002      0.284023         0.134711        0.010743
# 5      60.566726      0.349964         0.165536        0.034692
# 6      58.006089      2.223285         0.129770        0.010928
# 7      67.881209      2.609037         0.099727        0.012330
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                            0.15                           2
# 1                            0.15                           2
# 2                            0.15                           3
# 3                            0.15                           3
# 4                             0.2                           2
# 5                             0.2                           2
# 6                             0.2                           3
# 7                             0.2                           3
#
#   param_classifier__n_estimators  \
# 0                            100
# 1                            150
# 2                            100
# 3                            150
# 4                            100
# 5                            150
# 6                            100
# 7                            150
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.15, 'classifie...           0.860465
# 1  {'classifier__learning_rate': 0.15, 'classifie...           0.863395
# 2  {'classifier__learning_rate': 0.15, 'classifie...           0.864951
# 3  {'classifier__learning_rate': 0.15, 'classifie...           0.868614
# 4  {'classifier__learning_rate': 0.2, 'classifier...           0.861930
# 5  {'classifier__learning_rate': 0.2, 'classifier...           0.865867
# 6  {'classifier__learning_rate': 0.2, 'classifier...           0.867149
# 7  {'classifier__learning_rate': 0.2, 'classifier...           0.868797
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.860374           0.857522           0.858438           0.858896
# 1           0.863853           0.861826           0.860452           0.862284
# 2           0.866691           0.864481           0.865122           0.862558
# 3           0.869713           0.864664           0.864848           0.864939
# 4           0.864768           0.860544           0.860269           0.861368
# 5           0.868248           0.863657           0.863199           0.863382
# 6           0.866783           0.865397           0.864115           0.863566
# 7           0.869896           0.866587           0.865397           0.865672
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.859139        0.001136                8
# 1         0.862362        0.001202                6
# 2         0.864761        0.001328                5
# 3         0.866555        0.002159                2
# 4         0.861776        0.001608                7
# 5         0.864871        0.001943                4
# 6         0.865402        0.001413                3
# 7         0.867270        0.001775                1

# %% [markdown]
# ## Second try with M1 Pro

# %%
hyper_param = {"classifier__n_estimators":[100, 150, 200],
              "classifier__learning_rate":[0.3, 0.4, 0.5],
              "classifier__max_depth":[2, 3]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.3, 0.4, 0.5],
#                          'classifier__max_depth': [2, 3],
#                          'classifier__n_estimators': [100, 150, 200]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       39.077009      0.066949         0.120705        0.005661
# 1       58.091230      0.177817         0.136859        0.010335
# 2       76.772948      0.324281         0.147263        0.008210
# 3       56.501519      0.152837         0.139063        0.011240
# 4       85.919472      0.824001         0.158863        0.015478
# 5      118.381177      0.809498         0.187784        0.015779
# 6       41.305494      0.488099         0.135536        0.013497
# 7       59.908600      0.226885         0.154970        0.032697
# 8       79.209472      0.201033         0.146366        0.013671
# 9       57.690893      0.468243         0.139383        0.003349
# 10      85.941391      0.077929         0.160730        0.007344
# 11     113.672018      0.271455         0.168736        0.017191
# 12      38.714270      0.074445         0.119834        0.002148
# 13      57.924252      0.119447         0.140854        0.006492
# 14      78.105226      0.427447         0.147680        0.010071
# 15      58.512729      0.676478         0.134112        0.003884
# 16      88.446891      0.389891         0.157318        0.021439
# 17      93.134537     11.583989         0.108151        0.012390
#
#    param_classifier__learning_rate param_classifier__max_depth  \
# 0                              0.3                           2
# 1                              0.3                           2
# 2                              0.3                           2
# 3                              0.3                           3
# 4                              0.3                           3
# 5                              0.3                           3
# 6                              0.4                           2
# 7                              0.4                           2
# 8                              0.4                           2
# 9                              0.4                           3
# 10                             0.4                           3
# 11                             0.4                           3
# 12                             0.5                           2
# 13                             0.5                           2
# 14                             0.5                           2
# 15                             0.5                           3
# 16                             0.5                           3
# 17                             0.5                           3
#
#    param_classifier__n_estimators  \
# 0                             100
# 1                             150
# 2                             200
# 3                             100
# 4                             150
# 5                             200
# 6                             100
# 7                             150
# 8                             200
# 9                             100
# 10                            150
# 11                            200
# 12                            100
# 13                            150
# 14                            200
# 15                            100
# 16                            150
# 17                            200
#
#                                                params  split0_test_score  \
# 0   {'classifier__learning_rate': 0.3, 'classifier...           0.866416
# 1   {'classifier__learning_rate': 0.3, 'classifier...           0.869438
# 2   {'classifier__learning_rate': 0.3, 'classifier...           0.870170
# 3   {'classifier__learning_rate': 0.3, 'classifier...           0.868064
# 4   {'classifier__learning_rate': 0.3, 'classifier...           0.869987
# 5   {'classifier__learning_rate': 0.3, 'classifier...           0.871177
# 6   {'classifier__learning_rate': 0.4, 'classifier...           0.867515
# 7   {'classifier__learning_rate': 0.4, 'classifier...           0.868797
# 8   {'classifier__learning_rate': 0.4, 'classifier...           0.870628
# 9   {'classifier__learning_rate': 0.4, 'classifier...           0.869163
# 10  {'classifier__learning_rate': 0.4, 'classifier...           0.869987
# 11  {'classifier__learning_rate': 0.4, 'classifier...           0.871177
# 12  {'classifier__learning_rate': 0.5, 'classifier...           0.869804
# 13  {'classifier__learning_rate': 0.5, 'classifier...           0.870811
# 14  {'classifier__learning_rate': 0.5, 'classifier...           0.872001
# 15  {'classifier__learning_rate': 0.5, 'classifier...           0.867698
# 16  {'classifier__learning_rate': 0.5, 'classifier...           0.868522
# 17  {'classifier__learning_rate': 0.5, 'classifier...           0.868156
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.866966           0.862192           0.862925
# 1            0.867698           0.865031           0.864481
# 2            0.867973           0.864390           0.867503
# 3            0.870445           0.864573           0.865855
# 4            0.872642           0.866221           0.867320
# 5            0.872642           0.865763           0.866587
# 6            0.868888           0.865672           0.863749
# 7            0.870811           0.867320           0.865946
# 8            0.872368           0.867137           0.866679
# 9            0.872276           0.864481           0.867411
# 10           0.873741           0.864939           0.866862
# 11           0.875023           0.866129           0.867411
# 12           0.868705           0.864848           0.863199
# 13           0.869896           0.865672           0.866221
# 14           0.871361           0.867320           0.868327
# 15           0.869346           0.866313           0.866404
# 16           0.869438           0.866129           0.866313
# 17           0.872001           0.865672           0.866954
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.863291         0.864358        0.001945               18
# 1            0.865031         0.866336        0.001914               15
# 2            0.865031         0.867013        0.002095               13
# 3            0.865397         0.866867        0.002130               14
# 4            0.866770         0.868588        0.002405                5
# 5            0.869151         0.869064        0.002619                3
# 6            0.862284         0.865622        0.002405               17
# 7            0.866129         0.867801        0.001818                8
# 8            0.867137         0.868790        0.002285                4
# 9            0.865031         0.867673        0.002851               10
# 10           0.867228         0.868552        0.003054                6
# 11           0.867686         0.869485        0.003235                2
# 12           0.863840         0.866079        0.002668               16
# 13           0.866862         0.867892        0.002065                7
# 14           0.868510         0.869504        0.001835                1
# 15           0.865580         0.867068        0.001328               12
# 16           0.866221         0.867325        0.001384               11
# 17           0.865580         0.867673        0.002361                9

# %% [markdown]
# ## Third try with M1 Pro

# %%
hyper_param = {"classifier__n_estimators":[150, 200, 250, 300],
              "classifier__learning_rate":[0.4, 0.5],
              "classifier__max_depth":[2, 3]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.4, 0.5],
#                          'classifier__max_depth': [2, 3],
#                          'classifier__n_estimators': [150, 200, 250, 300]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       60.362338      0.209580         0.137881        0.015437
# 1       80.182985      0.416017         0.151310        0.011869
# 2      101.049779      0.420139         0.179223        0.011707
# 3      121.588579      0.489774         0.188961        0.020416
# 4       90.283707      0.449566         0.162812        0.006480
# 5      121.664599      0.557375         0.190112        0.014766
# 6      151.877410      0.514000         0.208406        0.020232
# 7      179.903068      0.224888         0.225624        0.022092
# 8       60.140477      0.670912         0.146992        0.021426
# 9       80.790621      0.329842         0.163348        0.009247
# 10     101.032145      0.107572         0.160006        0.019420
# 11     119.107573      0.368044         0.187787        0.016080
# 12      87.653767      0.382755         0.161914        0.018520
# 13     117.370488      0.272750         0.190053        0.023493
# 14     143.140973      3.346311         0.196620        0.031191
# 15     144.450092     12.101648         0.130862        0.022001
#
#    param_classifier__learning_rate param_classifier__max_depth  \
# 0                              0.4                           2
# 1                              0.4                           2
# 2                              0.4                           2
# 3                              0.4                           2
# 4                              0.4                           3
# 5                              0.4                           3
# 6                              0.4                           3
# 7                              0.4                           3
# 8                              0.5                           2
# 9                              0.5                           2
# 10                             0.5                           2
# 11                             0.5                           2
# 12                             0.5                           3
# 13                             0.5                           3
# 14                             0.5                           3
# 15                             0.5                           3
#
#    param_classifier__n_estimators  \
# 0                             150
# 1                             200
# 2                             250
# 3                             300
# 4                             150
# 5                             200
# 6                             250
# 7                             300
# 8                             150
# 9                             200
# 10                            250
# 11                            300
# 12                            150
# 13                            200
# 14                            250
# 15                            300
#
#                                                params  split0_test_score  \
# 0   {'classifier__learning_rate': 0.4, 'classifier...           0.868797
# 1   {'classifier__learning_rate': 0.4, 'classifier...           0.870628
# 2   {'classifier__learning_rate': 0.4, 'classifier...           0.870811
# 3   {'classifier__learning_rate': 0.4, 'classifier...           0.871452
# 4   {'classifier__learning_rate': 0.4, 'classifier...           0.869987
# 5   {'classifier__learning_rate': 0.4, 'classifier...           0.871177
# 6   {'classifier__learning_rate': 0.4, 'classifier...           0.870628
# 7   {'classifier__learning_rate': 0.4, 'classifier...           0.871818
# 8   {'classifier__learning_rate': 0.5, 'classifier...           0.870811
# 9   {'classifier__learning_rate': 0.5, 'classifier...           0.872001
# 10  {'classifier__learning_rate': 0.5, 'classifier...           0.872368
# 11  {'classifier__learning_rate': 0.5, 'classifier...           0.871452
# 12  {'classifier__learning_rate': 0.5, 'classifier...           0.868522
# 13  {'classifier__learning_rate': 0.5, 'classifier...           0.868156
# 14  {'classifier__learning_rate': 0.5, 'classifier...           0.869163
# 15  {'classifier__learning_rate': 0.5, 'classifier...           0.868431
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.870811           0.867320           0.865946
# 1            0.872368           0.867137           0.866679
# 2            0.873558           0.867869           0.868327
# 3            0.873009           0.868327           0.868052
# 4            0.873741           0.864939           0.866862
# 5            0.875023           0.866129           0.867411
# 6            0.874931           0.866404           0.868785
# 7            0.874657           0.867228           0.867961
# 8            0.869896           0.865672           0.866221
# 9            0.871361           0.867320           0.868327
# 10           0.871269           0.868419           0.868785
# 11           0.871818           0.867411           0.868602
# 12           0.869438           0.866129           0.866313
# 13           0.872001           0.865672           0.866954
# 14           0.871452           0.864664           0.867686
# 15           0.870720           0.866221           0.867228
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.866129         0.867801        0.001818               14
# 1            0.867137         0.868790        0.002285                9
# 2            0.868419         0.869797        0.002142                3
# 3            0.870342         0.870236        0.001876                1
# 4            0.867228         0.868552        0.003054               10
# 5            0.867686         0.869485        0.003235                8
# 6            0.867411         0.869632        0.003005                5
# 7            0.866404         0.869614        0.003131                6
# 8            0.866862         0.867892        0.002065               13
# 9            0.868510         0.869504        0.001835                7
# 10           0.868236         0.869815        0.001681                2
# 11           0.869060         0.869669        0.001697                4
# 12           0.866221         0.867325        0.001384               16
# 13           0.865580         0.867673        0.002361               15
# 14           0.867503         0.868094        0.002223               11
# 15           0.867137         0.867947        0.001554               12

# %%
# One se-rule
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5     121.664599      0.557375         0.190112        0.014766
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 5                             0.4                           3
#
#   param_classifier__n_estimators  \
# 5                            200
#
#                                               params  split0_test_score  \
# 5  {'classifier__learning_rate': 0.4, 'classifier...           0.871177
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 5           0.875023           0.866129           0.867411           0.867686
#
#    mean_test_score  std_test_score  rank_test_score
# 5         0.869485        0.003235                8

# %% [markdown]
# ### Exporting the predictions to .csv

# %%
clf.set_params(classifier__learning_rate = 0.4, classifier__n_estimators = 200, classifier__max_depth = 3)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.4, n_estimators=200,
#                                             random_state=1))])

# %%
clf.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'class_worker', 'mig_same',
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.4, n_estimators=200,
#                                             random_state=1))])

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
GB_tree_200_LR04_max_depth_3 = test_df[["id"]]
GB_tree_200_LR04_max_depth_3["high_income"] = y_pred
GB_tree_200_LR04_max_depth_3
# Out:
# /var/folders/j_/j3q5g8gs44n5d1rkmyq_rtv40000gn/T/ipykernel_8782/3187700655.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_200_LR04_max_depth_3["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_200_LR04_max_depth_3.to_csv("Predictions/GB_tree_200_LR04_max_depth_3.csv",index = False, header=True)

# %% [markdown]
# # Fourth Try

# %%
hyper_param = {"classifier__n_estimators":[100],
              "classifier__learning_rate":[0.4],
              "classifier__max_depth":[2],
              "classifier__max_features":[21]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
#       Iter       Train Loss   Remaining Time
#          1           1.1837            6.21s
#          2           1.1022            5.88s
#          3           1.0721            5.82s
#          4           1.0114            5.75s
#          5           0.9575            5.78s
#          6           0.9060            5.78s
#          7           0.8815            5.70s
#          8           0.8516            5.69s
#          9           0.8407            5.63s
#         10           0.8273            5.58s
#         20           0.7164            5.10s
#         30           0.6775            4.49s
#         40           0.6571            3.83s
#         50           0.6443            3.17s
#         60           0.6319            2.52s
#         70           0.6230            1.89s
#         80           0.6179            1.25s
#         90           0.6112            0.62s
#        100           0.6065            0.00s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=10,
#                                                                    verbose=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.4],
#                          'classifier__max_depth': [2],
#                          'classifier__max_features': [21],
#                          'classifier__n_estimators': [100]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      11.597692      2.185763         0.423105        0.085905
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                             0.4                           2
#
#   param_classifier__max_features param_classifier__n_estimators  \
# 0                             21                            100
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.4, 'classifier...           0.861198
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.864494           0.854684           0.858346           0.859262
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.859597        0.003236                1

# %%
clf.set_params(classifier__learning_rate = 0.4, classifier__n_estimators = 100, classifier__max_depth = 2, classifier__max_features = 21)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.4, max_depth=2,
#                                             max_features=21, random_state=10,
#                                             verbose=1))])

# %%
clf.fit(X,y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.1837            6.56s
#          2           1.1022            6.54s
#          3           1.0721            6.33s
#          4           1.0114            6.69s
#          5           0.9575            6.73s
#          6           0.9060            6.60s
#          7           0.8815            6.47s
#          8           0.8516            6.58s
#          9           0.8407            6.45s
#         10           0.8273            6.44s
#         20           0.7164            5.42s
#         30           0.6775            4.73s
#         40           0.6571            4.02s
#         50           0.6443            3.33s
#         60           0.6319            2.65s
#         70           0.6230            1.99s
#         80           0.6179            1.33s
#         90           0.6112            0.66s
#        100           0.6065            0.00s
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.4, max_depth=2,
#                                             max_features=21, random_state=10,
#                                             verbose=1))])

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
y_pred[:10]
# Out:
# array([0, 0, 0, 1, 0, 0, 1, 0, 0, 1])
#       Iter       Train Loss   Remaining Time
#          1           1.1461           10.65s
#          2           1.1111            9.87s
#          3           1.0266            9.73s
#          4           0.9913            9.65s
#          5           0.9442            9.73s
#          6           0.9117            9.81s
#          7           0.8949            9.53s
#          8           0.8823            9.32s
#          9           0.8702            9.14s
#         10           0.8338            9.05s
#         20           0.7254            8.10s
#         30           0.6822            7.02s
#         40           0.6560            6.03s
#         50           0.6380            5.03s
#         60           0.6284            3.98s
#         70           0.6214            2.96s
#         80           0.6144            1.96s
#         90           0.6082            0.99s
#        100           0.6031            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.1468           12.02s
#          2           1.1124           10.34s
#          3           1.0266           10.06s
#          4           0.9896            9.80s
#          5           0.9448           10.00s
#          6           0.9129            9.91s
#          7           0.8969            9.74s
#          8           0.8836            9.45s
#          9           0.8720            9.25s
#         10           0.8341            9.16s
#         20           0.7271            8.14s
#         30           0.6868            7.06s
#         40           0.6615            6.08s
#         50           0.6418            5.05s
#         60           0.6312            3.99s
#         70           0.6244            2.99s
#         80           0.6173            1.98s
#         90           0.6119            1.00s
#        100           0.6078            0.00s

# %%
GB_tree_100_LR04_max_depth_2_max_feat_21 = test_df[["id"]]
GB_tree_100_LR04_max_depth_2_max_feat_21["high_income"] = y_pred
GB_tree_100_LR04_max_depth_2_max_feat_21
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_25643/3493785903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_100_LR04_max_depth_2_max_feat_21["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_100_LR04_max_depth_2_max_feat_21.to_csv("Predictions/GB_tree_100_LR04_max_depth_2_max_feat_21.csv",index = False, header=True)

# %%
hyper_param = {"classifier__n_estimators":[300],
              "classifier__learning_rate":[0.1],
              "classifier__max_depth":[2],
              "classifier__max_features":[21]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
#       Iter       Train Loss   Remaining Time
#          1           1.2193           18.08s
#          2           1.1924           17.46s
#          3           1.1806           17.26s
#          4           1.1477           17.31s
#          5           1.1179           17.89s
#          6           1.0943           17.89s
#          7           1.0778           17.83s
#          8           1.0592           18.18s
#          9           1.0438           18.10s
#         10           1.0289           17.94s
#         20           0.9075           17.41s
#         30           0.8340           16.87s
#         40           0.7875           16.38s
#         50           0.7571           16.45s
#         60           0.7372           15.78s
#         70           0.7187           15.13s
#         80           0.7042           14.52s
#         90           0.6919           13.88s
#        100           0.6816           13.07s
#        200           0.6339            6.37s
#        300           0.6127            0.00s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(learning_rate=0.4,
#                                                                    max_depth=2,
#                                                                    max_features=21,
#                                                                    random_state=10,
#                                                                    verbose=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.1],
#                          'classifier__max_depth': [2],
#                          'classifier__max_features': [21],
#                          'classifier__n_estimators': [300]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      25.216032      5.451491         0.450497        0.105791
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                             0.1                           2
#
#   param_classifier__max_features param_classifier__n_estimators  \
# 0                             21                            300
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.1, 'classifier...           0.862022
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.863761           0.857431           0.860452           0.857248
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.860183        0.002548                1

# %% [markdown]
# ## It seems that for a tree to be more robust it needs a lower learning rate, this is what we will try !

# %%
hyper_param = {"classifier__n_estimators":[100, 150],
              "classifier__learning_rate":[0.05, 0.01],
              "classifier__max_depth":[2]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.05, 0.01],
#                          'classifier__max_depth': [2],
#                          'classifier__n_estimators': [100, 150]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      40.528996      0.124869         0.162459        0.007154
# 1      58.607755      1.215186         0.147949        0.018515
# 2      38.036877      0.157853         0.122410        0.002203
# 3      45.829656      4.600819         0.101942        0.016656
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                            0.05                           2
# 1                            0.05                           2
# 2                            0.01                           2
# 3                            0.01                           2
#
#   param_classifier__n_estimators  \
# 0                            100
# 1                            150
# 2                            100
# 3                            150
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.05, 'classifie...           0.844351
# 1  {'classifier__learning_rate': 0.05, 'classifie...           0.850485
# 2  {'classifier__learning_rate': 0.01, 'classifie...           0.807361
# 3  {'classifier__learning_rate': 0.01, 'classifie...           0.814045
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.846548           0.844703           0.843879           0.847541
# 1           0.855063           0.850105           0.850105           0.853768
# 2           0.813587           0.812105           0.808442           0.809999
# 3           0.817982           0.816775           0.808534           0.815676
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.845404        0.001400                2
# 1         0.851905        0.002095                1
# 2         0.810299        0.002291                4
# 3         0.814602        0.003299                3

# %%
hyper_param = {"classifier__n_estimators":[200, 250, 300,350,400,450,500],
              "classifier__learning_rate":[0.05],
              "classifier__max_depth":[2]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
#       Iter       Train Loss   Remaining Time
#          1           1.2019            7.19m
#          2           1.1742            7.14m
#          3           1.1462            7.00m
#          4           1.1211            6.93m
#          5           1.1004            6.67m
#          6           1.0795            6.44m
#          7           1.0616            6.50m
#          8           1.0453            6.49m
#          9           1.0283            6.48m
#         10           1.0147            6.46m
#         20           0.9093            6.02m
#         30           0.8481            5.59m
#         40           0.8076            5.21m
#         50           0.7781            4.99m
#         60           0.7562            4.68m
#         70           0.7388            4.46m
#         80           0.7245            4.22m
#         90           0.7136            3.91m
#        100           0.7033            3.63m
#        200           0.6524            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.2046            8.95m
#          2           1.1767            9.26m
#          3           1.1484            9.81m
#          4           1.1230            9.86m
#          5           1.1000            9.74m
#          6           1.0809            9.54m
#          7           1.0632            9.46m
#          8           1.0471            9.28m
#          9           1.0298            9.20m
#         10           1.0162            9.22m
#         20           0.9106            8.83m
#         30           0.8471            8.34m
#         40           0.8074            7.77m
#         50           0.7786            7.22m
#         60           0.7563            6.80m
#         70           0.7387            6.36m
#         80           0.7246            5.81m
#         90           0.7126            5.40m
#        100           0.7026            5.05m
#        200           0.6506            1.77m
#       Iter       Train Loss   Remaining Time
#          1           1.2019           10.13m
#          2           1.1742           10.02m
#          3           1.1462           10.26m
#          4           1.1211           10.32m
#          5           1.1004           10.27m
#          6           1.0795           10.15m
#          7           1.0616           10.16m
#          8           1.0453           10.08m
#          9           1.0283           10.02m
#         10           1.0147            9.95m
#         20           0.9093            9.42m
#         30           0.8481            9.21m
#         40           0.8076            8.80m
#         50           0.7781            8.43m
#         60           0.7562            8.07m
#         70           0.7388            7.73m
#         80           0.7245            7.40m
#         90           0.7136            7.08m
#        100           0.7033            6.74m
#        200           0.6524            3.38m
#        300           0.6296            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.2015           11.15m
#          2           1.1735           11.26m
#          3           1.1453           11.31m
#          4           1.1199           11.25m
#          5           1.0989           11.28m
#          6           1.0778           11.22m
#          7           1.0601           11.24m
#          8           1.0441           11.19m
#          9           1.0269           11.14m
#         10           1.0135           11.14m
#         20           0.9079           10.33m
#         30           0.8447            9.84m
#         40           0.8042            9.69m
#         50           0.7757            9.54m
#         60           0.7539            9.32m
#         70           0.7372            9.07m
#         80           0.7229            8.90m
#         90           0.7118            8.58m
#        100           0.7016            8.26m
#        200           0.6505            4.98m
#        300           0.6273            1.66m
#       Iter       Train Loss   Remaining Time
#          1           1.2044           11.23m
#          2           1.1763           11.40m
#          3           1.1481          188.94m
#          4           1.1251          145.27m
#          5           1.1018          118.15m
#          6           1.0807          100.09m
#          7           1.0630           87.28m
#          8           1.0470           78.25m
#          9           1.0298           73.74m
#         10           1.0163           67.82m
#         20           0.9099           52.57m
#         30           0.8474          354.32m
#         40           0.8086          286.57m
#         50           0.7798          224.86m
#         60           0.7571          183.18m
#         70           0.7401          153.04m
#         80           0.7260          130.46m
#         90           0.7130          112.84m
0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.2044           18.29m
#          2           1.1763           19.49m
#          3           1.1481           18.76m
#          4           1.1251           18.36m
#          5           1.1018           18.88m
#          6           1.0807           19.09m
#          7           1.0630           18.94m
#          8           1.0470           18.87m
#          9           1.0298           18.69m
#         10           1.0163           18.38m
#         20           0.9099           16.72m
#         30           0.8474           15.86m
#         40           0.8086           15.99m
#         50           0.7798           15.66m
#         60           0.7571           14.93m
#         70           0.7401           14.38m
#         80           0.7260           13.75m
#         90           0.7130           13.22m
#        100           0.7028           12.79m
#        200           0.6511            8.78m
#        300           0.6282            5.60m
#        400           0.6147            2.55m
#        500           0.6053            0.00s
#        300           0.6292            4.29m
#        400           0.6151            2.12m
#        500           0.6058            0.00s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=10,
#                                                                    verbose=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.05],
#                          'classifier__max_depth': [2],
#                          'classifier__n_estimators': [200, 250, 300, 350, 400,
#                                                       450, 500]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     439.011922      5.684243         0.544244        0.087496
# 1     515.214100      8.080203         0.656658        0.045148
# 2     605.466142      6.854841         0.722937        0.037536
# 3    2474.484029    887.433849         0.869005        0.098129
# 4     876.132262      7.018124         0.912090        0.107991
# 5     979.451638      6.315458         1.108599        0.273493
# 6     925.680881    145.205593         0.824110        0.416121
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                            0.05                           2
# 1                            0.05                           2
# 2                            0.05                           2
# 3                            0.05                           2
# 4                            0.05                           2
# 5                            0.05                           2
# 6                            0.05                           2
#
#   param_classifier__n_estimators  \
# 0                            200
# 1                            250
# 2                            300
# 3                            350
# 4                            400
# 5                            450
# 6                            500
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.05, 'classifie...           0.855063
# 1  {'classifier__learning_rate': 0.05, 'classifie...           0.856803
# 2  {'classifier__learning_rate': 0.05, 'classifie...           0.859458
# 3  {'classifier__learning_rate': 0.05, 'classifie...           0.860374
# 4  {'classifier__learning_rate': 0.05, 'classifie...           0.861655
# 5  {'classifier__learning_rate': 0.05, 'classifie...           0.863578
# 6  {'classifier__learning_rate': 0.05, 'classifie...           0.864036
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.857627           0.854775           0.853585           0.856149
# 1           0.859458           0.856790           0.856698           0.856515
# 2           0.860099           0.858072           0.857797           0.858621
# 3           0.861198           0.859811           0.859995           0.859537
# 4           0.862388           0.859903           0.860819           0.860178
# 5           0.862846           0.860727           0.861185           0.861734
# 6           0.863761           0.861734           0.862009           0.861643
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.855440        0.001365                7
# 1         0.857253        0.001107                6
# 2         0.858809        0.000859                5
# 3         0.860183        0.000576                4
# 4         0.860988        0.000924                3
# 5         0.862014        0.001055                2
# 6         0.862637        0.001041                1

# %%
# One se-rule
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6     925.680881    145.205593          0.82411        0.416121
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 6                            0.05                           2
#
#   param_classifier__n_estimators  \
# 6                            500
#
#                                               params  split0_test_score  \
# 6  {'classifier__learning_rate': 0.05, 'classifie...           0.864036
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 6           0.863761           0.861734           0.862009           0.861643
#
#    mean_test_score  std_test_score  rank_test_score
# 6         0.862637        0.001041                1

# %%
# Very interesting CV score of 0.862637 --> Let's try it 
clf.set_params(classifier__learning_rate = 0.05, classifier__n_estimators = 500, classifier__max_depth = 2)
clf.fit(X,y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.2030           10.94m
#          2           1.1750           10.70m
#          3           1.1469           10.53m
#          4           1.1216           10.63m
#          5           1.1007           10.57m
#          6           1.0796           10.51m
#          7           1.0619           10.48m
#          8           1.0458           10.43m
#          9           1.0286           10.39m
#         10           1.0151           10.32m
#         20           0.9097            9.40m
#         30           0.8464            8.95m
#         40           0.8071            8.61m
#         50           0.7775            8.41m
#         60           0.7564            8.32m
#         70           0.7382            8.21m
#         80           0.7245            8.20m
#         90           0.7132            8.17m
#        100           0.7025            8.11m
#        200           0.6512            6.44m
#        300           0.6292            4.39m
#        400           0.6151            2.20m
#        500           0.6058            0.00s
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.05, max_depth=2,
#                                             n_estimators=500, random_state=10,
#                                             verbose=1))])

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
y_pred[:10]
# Out:
# array([0, 0, 0, 1, 0, 0, 0, 0, 0, 1])

# %%
GB_tree_500_LR0_05_max_depth_2 = test_df[["id"]]
GB_tree_500_LR0_05_max_depth_2["high_income"] = y_pred
GB_tree_500_LR0_05_max_depth_2
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_27213/2854562568.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_500_LR0_05_max_depth_2["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_500_LR0_05_max_depth_2.to_csv("Predictions/GB_tree_500_LR0_05_max_depth_2.csv",index = False, header=True)
# Worse score than when using 600 tree --> need to increase the nb of tree had a cv of 0.863662

# %% [markdown]
# # Final try :

# %%
hyper_param = {"classifier__n_estimators":[700,800,900,1000],
              "classifier__learning_rate":[0.05],
              "classifier__max_depth":[2]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#       Iter       Train Loss   Remaining Time
#          1           1.2019           30.95m
#          2           1.1742           28.91m
#          3           1.1462           28.59m
#          4           1.1211           28.18m
#          5           1.1004           28.20m
#          6           1.0795           28.15m
#          7           1.0616           28.09m
#          8           1.0453           27.96m
#          9           1.0283           27.88m
#         10           1.0147           27.77m
#         20           0.9093           27.27m
#         30           0.8481           26.13m
#         40           0.8076           25.59m
#         50           0.7781           24.99m
#         60           0.7562           24.46m
#         70           0.7388           23.92m
#         80           0.7245           23.41m
#         90           0.7136           23.01m
#        100           0.7033           22.71m
#        200           0.6524           19.00m
#        300           0.6296           15.21m
#        400           0.6166           32.81m
#        500           0.6072           18.96m
#        600           0.5999            8.45m
#        700           0.5940            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.2044           22.70m
#          2           1.1763           20.54m
#          3           1.1481           18.72m
#          4           1.1251           17.58m
#          5           1.1018           16.74m
#          6           1.0807           16.17m
#          7           1.0630           15.94m
#          8           1.0470           16.68m
#          9           1.0298           17.38m
#         10           1.0163           17.91m
#         20           0.9099           20.80m
#         30           0.8474           21.27m
#         40           0.8086           21.38m
#         50           0.7798           21.52m
#         60           0.7571           21.24m
#         70           0.7401           20.98m
#         80           0.7260           20.81m
#         90           0.7130           20.46m
#        100           0.7028           20.16m
#        200           0.6511           16.85m
#        300           0.6282           13.94m
#        400           0.6147           10.36m
#        500           0.6053            6.89m
#        600           0.5979            3.44m
#        700           0.5916            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.
0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.2015           32.43m
#          2           1.1735           32.18m
#          3           1.1453           32.28m
#          4           1.1199           32.26m
#          5           1.0989           32.23m
#          6           1.0778           31.83m
#          7           1.0601           31.84m
#          8           1.0441           32.20m
#          9           1.0269           32.15m
#         10           1.0135           32.11m
#         20           0.9079           30.70m
#         30           0.8447           30.39m
#         40           0.8042           30.62m
#         50           0.7757           31.36m
#         60           0.7539           31.29m
#         70           0.7372           31.07m
#         80           0.7229           31.15m
#         90           0.7118           30.93m
#        100           0.7016           30.68m
#        200           0.6505           54.69m
#        300           0.6273           45.03m
#        400           0.6135           33.97m
#        500           0.6037           25.99m
#        600           0.5962           19.61m
#        700           0.5904           14.18m
#        800           0.5856            9.18m
#        900           0.5819            4.46m
#       1000           0.5780            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.2044           32.32m
#          2           1.1763           33.25m
#          3           1.1481           33.50m
#          4           1.1251           33.92m
#          5           1.1018           34.64m
#          6           1.0807           34.79m
#          7           1.0630           35.03m
#          8           1.0470           34.84m
#          9           1.0298           35.72m
#         10           1.0163           35.76m
#         20           0.9099           37.96m
#         30           0.8474           37.10m
#         40           0.8086           35.98m
#         50           0.7798           35.11m
#         60           0.7571           34.32m
#         70           0.7401           34.22m
#         80           0.7260           33.53m
#         90           0.7130           32.81m
#        100           0.7028           32.33m
#        200           0.6511           28.32m
#        300           0.6282           24.37m
#        400           0.6147           20.86m
#        500           0.6053           17.23m
#        600           0.5979           13.72m
#        700           0.5916           10.36m
#        800           0.5865            6.73m
#        900           0.5825            3.20m
#       1000           0.5791            0.00s
#        300           0.6292           14.51m
#        400           0.6151           12.54m
#        500           0.6058           10.45m
#        600           0.5988            8.34m
#        700           0.5931            6.25m
#        800           0.5887           16.56m
#        900           0.5850            7.58m
#       1000           0.5812            0.00s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(learning_rate=0.05,
#                                                                    max_depth=2,
#                                                                    n_estimators=500,
#                                                                    random_state=10,
#                                                                    verbose=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.05],
#                          'classifier__max_depth': [2],
#                          'classifier__n_estimators': [700, 800, 900, 1000]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0    2887.199962    719.174211         1.134479        0.137871
# 1    1671.037972     15.835501         1.278044        0.095429
# 2    2201.491298    250.485545         1.334440        0.196536
# 3    2096.720058    276.138373         0.995380        0.301023
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 0                            0.05                           2
# 1                            0.05                           2
# 2                            0.05                           2
# 3                            0.05                           2
#
#   param_classifier__n_estimators  \
# 0                            700
# 1                            800
# 2                            900
# 3                           1000
#
#                                               params  split0_test_score  \
# 0  {'classifier__learning_rate': 0.05, 'classifie...           0.865959
# 1  {'classifier__learning_rate': 0.05, 'classifie...           0.867515
# 2  {'classifier__learning_rate': 0.05, 'classifie...           0.869255
# 3  {'classifier__learning_rate': 0.05, 'classifie...           0.869529
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.867424           0.863016           0.864023           0.863657
# 1           0.867607           0.863016           0.864573           0.863566
# 2           0.868705           0.864481           0.864756           0.863016
# 3           0.869621           0.864115           0.865397           0.863932
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.864816        0.001632                4
# 1         0.865255        0.001948                3
# 2         0.866043        0.002476                2
# 3         0.866519        0.002546                1

# %%
# One se-rule
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2    2201.491298    250.485545          1.33444        0.196536
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 2                            0.05                           2
#
#   param_classifier__n_estimators  \
# 2                            900
#
#                                               params  split0_test_score  \
# 2  {'classifier__learning_rate': 0.05, 'classifie...           0.869255
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 2           0.868705           0.864481           0.864756           0.863016
#
#    mean_test_score  std_test_score  rank_test_score
# 2         0.866043        0.002476                2

# %%
# Very interesting CV score of 0.866043 --> Let's try it 
clf.set_params(classifier__learning_rate = 0.05, classifier__n_estimators = 900, classifier__max_depth = 2)
clf.fit(X,y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.2030           23.60m
#          2           1.1750           22.76m
#          3           1.1469           22.94m
#          4           1.1216           23.16m
#          5           1.1007           22.84m
#          6           1.0796           22.43m
#          7           1.0619           22.06m
#          8           1.0458           21.73m
#          9           1.0286           21.61m
#         10           1.0151           21.53m
#         20           0.9097           19.96m
#         30           0.8464           19.34m
#         40           0.8071           18.86m
#         50           0.7775           18.66m
#         60           0.7564           18.25m
#         70           0.7382           17.94m
#         80           0.7245           17.73m
#         90           0.7132           17.45m
#        100           0.7025           17.18m
#        200           0.6512           15.61m
#        300           0.6292           13.17m
#        400           0.6151           10.79m
#        500           0.6058            8.65m
#        600           0.5988            6.48m
#        700           0.5931            4.31m
#        800           0.5887            2.16m
#        900           0.5850            0.00s
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.05, max_depth=2,
#                                             n_estimators=900, random_state=10,
#                                             verbose=1))])

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
y_pred[:10]
# Out:
# array([0, 0, 0, 1, 0, 0, 1, 0, 0, 1])

# %%
GB_tree_900_LR0_05_max_depth_2 = test_df[["id"]]
GB_tree_900_LR0_05_max_depth_2["high_income"] = y_pred
GB_tree_900_LR0_05_max_depth_2
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_27213/3180024720.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_900_LR0_05_max_depth_2["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_900_LR0_05_max_depth_2.to_csv("Predictions/GB_tree_900_LR0_05_max_depth_2.csv",index = False, header=True)
# cv score = 0.866043

# %% [markdown]
# # It takes to much time using a lot of tree and might overfit ! for this reason I will try low amount of tree :

# %%
hyper_param = {"classifier__n_estimators":[80,90,100],
              "classifier__learning_rate":[0.6,0.7,0.8,0.9],
              "classifier__max_depth":[2]}
boost_pipe_cv = GridSearchCV(estimator = clf,param_grid=hyper_param, scoring="accuracy",
                           cv = KFold(n_splits=5, shuffle=True, random_state=1), n_jobs=-1, verbose=1)

# %%
boost_pipe_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['occ_code_level2',
#                                                                           'age',
#                                                                           'stock_dividends',
#                                                                           'wage_per_hour',
#                                                                           'capital_losses',
#                                                                           'own_or_self',
#                                                                           'ind_code_level2',
#                                                                           'capital_gains',
#                                                                           'week...
#                                                                           'marital_stat',
#                                                                           'region_prev_res',
#                                                                           'mig_chg_reg',
#                                                                           'country_father',
#                                                                           'occ_code_level1',
#                                                                           'full_or_part_emp',
#                                                                           'det_hh_fam_stat'])])),
#                                        ('classifier',
#                                         GradientBoostingClassifier(max_depth=2,
#                                                                    random_state=1))]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.6, 0.7, 0.8, 0.9],
#                          'classifier__max_depth': [2],
#                          'classifier__n_estimators': [80, 90, 100]},
#              scoring='accuracy', verbose=1)

# %%
pd.DataFrame(boost_pipe_cv.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      172.952985      6.598915         0.412912        0.081954
# 1      209.123173      3.603136         0.494610        0.102585
# 2      219.928437     10.968266         0.552994        0.073124
# 3      165.632725      3.401566         0.513707        0.025718
# 4      181.463003      7.026478         0.514709        0.009378
# 5      208.312418     10.615847         0.508773        0.039877
# 6      159.053840      1.265936         0.491989        0.053776
# 7      184.796974      2.157964         0.495202        0.038192
# 8      203.920793      2.993018         0.501579        0.032405
# 9      159.647033      1.856604         0.497041        0.004276
# 10     177.097247      0.725108         0.512170        0.004179
# 11     183.366998     15.210621         0.373921        0.134289
#
#    param_classifier__learning_rate param_classifier__max_depth  \
# 0                              0.6                           2
# 1                              0.6                           2
# 2                              0.6                           2
# 3                              0.7                           2
# 4                              0.7                           2
# 5                              0.7                           2
# 6                              0.8                           2
# 7                              0.8                           2
# 8                              0.8                           2
# 9                              0.9                           2
# 10                             0.9                           2
# 11                             0.9                           2
#
#    param_classifier__n_estimators  \
# 0                              80
# 1                              90
# 2                             100
# 3                              80
# 4                              90
# 5                             100
# 6                              80
# 7                              90
# 8                             100
# 9                              80
# 10                             90
# 11                            100
#
#                                                params  split0_test_score  \
# 0   {'classifier__learning_rate': 0.6, 'classifier...           0.866691
# 1   {'classifier__learning_rate': 0.6, 'classifier...           0.867607
# 2   {'classifier__learning_rate': 0.6, 'classifier...           0.867149
# 3   {'classifier__learning_rate': 0.7, 'classifier...           0.865226
# 4   {'classifier__learning_rate': 0.7, 'classifier...           0.866233
# 5   {'classifier__learning_rate': 0.7, 'classifier...           0.868431
# 6   {'classifier__learning_rate': 0.8, 'classifier...           0.867698
# 7   {'classifier__learning_rate': 0.8, 'classifier...           0.866874
# 8   {'classifier__learning_rate': 0.8, 'classifier...           0.868248
# 9   {'classifier__learning_rate': 0.9, 'classifier...           0.865135
# 10  {'classifier__learning_rate': 0.9, 'classifier...           0.863761
# 11  {'classifier__learning_rate': 0.9, 'classifier...           0.864585
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.869529           0.863566           0.864664
# 1            0.871269           0.864023           0.863932
# 2            0.871544           0.863382           0.865672
# 3            0.869346           0.865855           0.863749
# 4            0.870720           0.865672           0.865031
# 5            0.869346           0.866770           0.864023
# 6            0.867790           0.864298           0.862375
# 7            0.867424           0.864481           0.865031
# 8            0.868156           0.864939           0.864481
# 9            0.869804           0.863108           0.865580
# 10           0.870628           0.862925           0.864207
# 11           0.870079           0.862467           0.863840
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.862192         0.865329        0.002565               10
# 1            0.863382         0.866043        0.003012                4
# 2            0.863016         0.866153        0.003092                3
# 3            0.860544         0.864944        0.002866               11
# 4            0.862192         0.865969        0.002752                5
# 5            0.862558         0.866226        0.002577                2
# 6            0.862558         0.864944        0.002383               12
# 7            0.865397         0.865841        0.001120                6
# 8            0.866587         0.866482        0.001569                1
# 9            0.865397         0.865805        0.002188                7
# 10           0.866038         0.865512        0.002754                8
# 11           0.865855         0.865365        0.002600                9

# %%
# One se-rule
cv_res = pd.DataFrame(boost_pipe_cv.cv_results_)
mean_scores = boost_pipe_cv.cv_results_["mean_test_score"]
best_index = np.argmax(mean_scores)
se_scores = boost_pipe_cv.cv_results_["std_test_score"] / np.sqrt(5)

one_stand_error_data_frame = cv_res[boost_pipe_cv.cv_results_["mean_test_score"] >=(mean_scores[best_index] - se_scores[best_index])]
one_stand_error_data_frame[one_stand_error_data_frame["mean_test_score"] == one_stand_error_data_frame["mean_test_score"].min()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9     159.647033      1.856604         0.497041        0.004276
#
#   param_classifier__learning_rate param_classifier__max_depth  \
# 9                             0.9                           2
#
#   param_classifier__n_estimators  \
# 9                             80
#
#                                               params  split0_test_score  \
# 9  {'classifier__learning_rate': 0.9, 'classifier...           0.865135
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9           0.869804           0.863108            0.86558           0.865397
#
#    mean_test_score  std_test_score  rank_test_score
# 9         0.865805        0.002188                7

# %%
# Very interesting CV score of 0.865805 --> Let's try it 
clf.set_params(classifier__learning_rate = 0.9, classifier__n_estimators = 80, classifier__max_depth = 2)
clf.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['occ_code_level2', 'age',
#                                                    'stock_dividends',
#                                                    'wage_per_hour',
#                                                    'capital_losses',
#                                                    'own_or_self',
#                                                    'ind_code_level2',
#                                                    'capital_gains',
#                                                    'weeks_worked', 'num_emp',
#                                                    'vet_benefits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_ca...
#                                                    'unemp_reason',
#                                                    'state_prev_res', 'race',
#                                                    'country_mother', 'sex',
#                                                    'ind_code_level1',
#                                                    'citizenship',
#                                                    'union_member',
#                                                    'fam_under_18',
#                                                    'marital_stat',
#                                                    'region_prev_res',
#                                                    'mig_chg_reg',
#                                                    'country_father',
#                                                    'occ_code_level1',
#                                                    'full_or_part_emp',
#                                                    'det_hh_fam_stat'])])),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.9, max_depth=2,
#                                             n_estimators=80, random_state=1))])

# %%
y_pred = clf.predict(test_df.drop("id",axis = 1))
y_pred[:10]
# Out:
# array([0, 0, 0, 1, 0, 0, 1, 0, 0, 1])

# %%
GB_tree_80_LR09_max_depth_2 = test_df[["id"]]
GB_tree_80_LR09_max_depth_2["high_income"] = y_pred
GB_tree_80_LR09_max_depth_2
# Out:
# /var/folders/r3/t8xp3_0d2qg9znqckxzmdc2w0000gp/T/ipykernel_32146/4085946031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GB_tree_80_LR09_max_depth_2["high_income"] = y_pred
#         id  high_income
# 0        1            0
# 1        2            0
# 2        3            0
# 3        4            1
# 4        5            0
# ...    ...          ...
# 6063  6064            0
# 6064  6065            1
# 6065  6066            0
# 6066  6067            0
# 6067  6068            1
#
# [6068 rows x 2 columns]

# %%
GB_tree_80_LR09_max_depth_2.to_csv("Predictions/GB_tree_80_LR09_max_depth_2.csv",index = False, header=True)
